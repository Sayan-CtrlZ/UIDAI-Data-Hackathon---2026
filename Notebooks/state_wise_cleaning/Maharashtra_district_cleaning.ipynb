# %% [markdown]
# # District Cleaning — Maharashtra
#
# This notebook standardizes **district names** for this state across:
# - Enrolment data
# - Demographic update data
# - Biometric update data
#
# **All data is saved back to the same cleaned files.**

# %%
import pandas as pd
from pathlib import Path

pd.set_option("display.max_rows", None)
pd.set_option("display.width", None)

CLEAN_DIR = Path("../../data/processed/cleaned")

enrol_df = pd.read_csv(CLEAN_DIR / "enrolment_clean.csv")
demo_df  = pd.read_csv(CLEAN_DIR / "demographic_clean.csv")
bio_df   = pd.read_csv(CLEAN_DIR / "biometric_clean.csv")

for df in [enrol_df, demo_df, bio_df]:
    df["state"] = df["state"].astype(str).str.strip().str.title()
    df["district"] = df["district"].astype(str).str.strip().str.title()

print("✅ All datasets loaded and normalized (Title Case)")
# Out:
# ✅ All datasets loaded and normalized (Title Case)

# %%
STATE_NAME = "Maharashtra"

districts = sorted(
    set(
        enrol_df.loc[enrol_df["state"] == STATE_NAME, "district"].dropna()
        .tolist()
    )
)

print(f"State: {STATE_NAME}")
print(f"Number of unique districts: {len(districts)}")

pd.DataFrame(
    {"District Name": districts}
)
# Out:
# State: Maharashtra
# Number of unique districts: 51
#                 District Name
# 0                  Ahmadnagar
# 1                 Ahmed Nagar
# 2                  Ahmednagar
# 3                       Akola
# 4                    Amravati
# 5                  Aurangabad
# 6                        Beed
# 7                    Bhandara
# 8                         Bid
# 9                     Buldana
# 10                   Buldhana
# 11                 Chandrapur
# 12  Chatrapati Sambhaji Nagar
# 13  Chhatrapati Sambhajinagar
# 14                  Dharashiv
# 15                      Dhule
# 16                 Gadchiroli
# 17                     Gondia
# 18                    Gondiya
# 19                  Gondiya *
# 20                    Hingoli
# 21                    Jalgaon
# 22                      Jalna
# 23                   Kolhapur
# 24                      Latur
# 25                     Mumbai
# 26                Mumbai City
# 27            Mumbai Suburban
# 28        Mumbai( Sub Urban )
# 29                     Nagpur
# 30                     Nanded
# 31                  Nandurbar
# 32                Nandurbar *
# 33                     Nashik
# 34                  Osmanabad
# 35                    Palghar
# 36                   Parbhani
# 37                       Pune
# 38                     Raigad
# 39                    Raigarh
# 40                Raigarh(Mh)
# 41                  Ratnagiri
# 42                     Sangli
# 43                     Satara
# 44                 Sindhudurg
# 45                    Solapur
# 46                      Thane
# 47                     Wardha
# 48                     Washim
# 49                   Washim *
# 50                   Yavatmal

# %% [markdown]
# ## District Mapping
#
# Add mappings in **Title Case only**.
#
# Format:
# ```python
# DISTRICT_MAPPING = {
#     "Correct District": ["Wrong Name 1", "Wrong Name 2"],
# }
# ```

# %%
DISTRICT_MAPPING = {
    # "Correct District": ["Wrong Variant 1", "Wrong Variant 2"]
    "Ahilyanagar": ["Ahmadnagar","Ahmed Nagar","Ahmednagar"],
    "Beed" : ["Bid"],
    "Chhatrapati Sambhajinagar": ["Aurangabad","Chatrapati Sambhaji Nagar"],
    "Buldhana": ["Buldana"],
    "Gondia": ["Gondiya","Gondiya *"],
    "Hingoli": ["Hingoli *"],
    "Nandurbar": ["Nandurbar *"],
    "Dharashiv": ["Osmanabad"],
    "Mumbai Suburban": ["Mumbai( Sub Urban )"],
    "Raigad" : ["Raigarh", "Raigarh(Mh)"],
    "Washim": ["Washim *"],
    "Mumbai City" : ["Mumbai"]
}

def apply_mapping(df, state, mapping, label):
    total = 0
    for correct, wrongs in mapping.items():
        mask = (
            (df["state"] == state) &
            (df["district"].isin(wrongs))
        )
        count = mask.sum()
        df.loc[mask, "district"] = correct
        total += count
        if count > 0:
            print(f"✔ {label} → {correct} : {count} rows fixed")
    return total

total_fixes = 0
total_fixes += apply_mapping(enrol_df, STATE_NAME, DISTRICT_MAPPING, "Enrolment")
total_fixes += apply_mapping(demo_df,  STATE_NAME, DISTRICT_MAPPING, "Demographic")
total_fixes += apply_mapping(bio_df,   STATE_NAME, DISTRICT_MAPPING, "Biometric")

print(f"✅ Total fixes in {STATE_NAME}: {total_fixes}")
# Out:
# ✔ Enrolment → Ahilyanagar : 571 rows fixed
# ✔ Enrolment → Beed : 44 rows fixed
# ✔ Enrolment → Chhatrapati Sambhajinagar : 328 rows fixed
# ✔ Enrolment → Buldhana : 85 rows fixed
# ✔ Enrolment → Gondia : 93 rows fixed
# ✔ Enrolment → Nandurbar : 22 rows fixed
# ✔ Enrolment → Dharashiv : 147 rows fixed
# ✔ Enrolment → Mumbai Suburban : 34 rows fixed
# ✔ Enrolment → Raigad : 215 rows fixed
# ✔ Enrolment → Washim : 3 rows fixed
# ✔ Enrolment → Mumbai City : 483 rows fixed
# ✔ Demographic → Ahilyanagar : 569 rows fixed
# ✔ Demographic → Beed : 65 rows fixed
# ✔ Demographic → Chhatrapati Sambhajinagar : 253 rows fixed
# ✔ Demographic → Buldhana : 120 rows fixed
# ✔ Demographic → Gondia : 99 rows fixed
# ✔ Demographic → Nandurbar : 17 rows fixed
# ✔ Demographic → Dharashiv : 155 rows fixed
# ✔ Demographic → Mumbai Suburban : 95 rows fixed
# ✔ Demographic → Raigad : 306 rows fixed
# ✔ Demographic → Washim : 13 rows fixed
# ✔ Demographic → Mumbai City : 501 rows fixed
# ✔ Biometric → Ahilyanagar : 2271 rows fixed
# ✔ Biometric → Beed : 303 rows fixed
# ✔ Biometric → Chhatrapati Sambhajinagar : 915 rows fixed
# ✔ Biometric → Buldhana : 536 rows fixed
# ✔ Biometric → Gondia : 446 rows fixed
# ✔ Biometric → Hingoli : 3 rows fixed
# ✔ Biometric → Nandurbar : 139 rows fixed
# ✔ Biometric → Dharashiv : 519 rows fixed
# ✔ Biometric → Mumbai Suburban : 452 rows fixed
# ✔ Biometric → Raigad : 1207 rows fixed
# ✔ Biometric → Washim : 103 rows fixed
# ✔ Biometric → Mumbai City : 1923 rows fixed
# ✅ Total fixes in Maharashtra: 13035

# %%
enrol_df.to_csv(CLEAN_DIR / "enrolment_clean.csv", index=False)
demo_df.to_csv(CLEAN_DIR / "demographic_clean.csv", index=False)
bio_df.to_csv(CLEAN_DIR / "biometric_clean.csv", index=False)

print("💾 All cleaned files saved successfully (overwritten)")
# Out:
# 💾 All cleaned files saved successfully (overwritten)
